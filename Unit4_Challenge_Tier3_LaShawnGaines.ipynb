# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties.describe()
# Out:
#                           Unnamed: 0  Unnamed: 34  Unnamed: 37  Unnamed: 47
# count                            349          0.0          0.0          0.0
# mean   2009-07-01 12:59:49.684813824          NaN          NaN          NaN
# min              1995-01-01 00:00:00          NaN          NaN          NaN
# 25%              2002-04-01 00:00:00          NaN          NaN          NaN
# 50%              2009-07-01 00:00:00          NaN          NaN          NaN
# 75%              2016-10-01 00:00:00          NaN          NaN          NaN
# max              2024-01-01 00:00:00          NaN          NaN          NaN
# std                              NaN          NaN          NaN          NaN

# %%
print(properties.head())
# Out:
#   Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaT      E09000001          E09000002    E09000003    E09000004
# 1 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
#
#          Brent      Bromley       Camden      Croydon       Ealing  ...  \
# 0    E09000005    E09000006    E09000007    E09000008    E09000009  ...
# 1  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069  ...
# 2  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551  ...
# 3  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288  ...
# 4  72965.63094  81124.41227   120097.899  68610.04641  82188.90498  ...
#
#     NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# ...

# %%
properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 49 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            349 non-null    datetime64[ns]
#  1   City of London        350 non-null    object
#  2   Barking & Dagenham    350 non-null    object
#  3   Barnet                350 non-null    object
#  4   Bexley                350 non-null    object
#  5   Brent                 350 non-null    object
#  6   Bromley               350 non-null    object
#  7   Camden                350 non-null    object
#  8   Croydon               350 non-null    object
#  9   Ealing                350 non-null    object
#  10  Enfield               350 non-null    object
#  11  Greenwich             350 non-null    object
#  12  Hackney               350 non-null    object
#  13  Hammersmith & Fulham  350 non-null    object
# ...

# %%
properties.isna().sum()
# Out:
# Unnamed: 0                1
# City of London            0
# Barking & Dagenham        0
# Barnet                    0
# Bexley                    0
# Brent                     0
# Bromley                   0
# Camden                    0
# Croydon                   0
# Ealing                    0
# Enfield                   0
# Greenwich                 0
# Hackney                   0
# Hammersmith & Fulham      0
# Haringey                  0
# Harrow                    0
# Havering                  0
# Hillingdon                0
# Hounslow                  0
# Islington                 0
# Kensington & Chelsea      0
# Kingston upon Thames      0
# Lambeth                   0
# Lewisham                  0
# Merton                    0
# Newham                    0
# Redbridge                 0
# Richmond upon Thames      0
# Southwark                 0
# Sutton                    0
# Tower Hamlets             0
# Waltham Forest            0
# Wandsworth                0
# ...

# %%
properties.tail()
# Out:
#     Unnamed: 0 City of London Barking & Dagenham  Barnet  Bexley   Brent  \
# 345 2023-09-01         851623             338040  587594  397784  531401
# 346 2023-10-01         866683             339090  582343  393681  535750
# 347 2023-11-01         807979             342089  585717  396968  529750
# 348 2023-12-01         738449             336162  579648  387785  510978
# 349 2024-01-01         715466             322220  579029  391782  532273
#
#     Bromley  Camden Croydon  Ealing  ... NORTH WEST YORKS & THE HUMBER  \
# 345  502096  833351  408909  533448  ...     215115             206849
# 346  501839  846090  402680  527435  ...     215672             210289
# 347  496876  828300  394945  514089  ...     215126             207852
# 348  498636  857654  394355  522217  ...     216338             204984
# 349  504764  797248  392498  515353  ...     215082             203571
#
#     EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  LONDON SOUTH EAST SOUTH WEST  \
# ...

# %%
properties.shape
# Out:
# (350, 49)

# %%
print(properties.index)
# Out:
# RangeIndex(start=0, stop=350, step=1)

# %%
properties.columns
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
#There are several blank columns that we can drop.  Unnamed: 34, Unnamed: 37, Unnamed: 47  The additional columns that are not part of the 32 boroughs appear to be heirarchical
#Other than Inner and Outer London, I was unable to find that all the others are outside of London (NORTH EAST, NORTH WEST, etc).  Will keep Inner, Outer, London & England for now. 
#they might be interesting for comparison purposes later.  All Others can go.

properties =  properties.drop(columns =['Unnamed: 34', 'Unnamed: 37', 'Unnamed: 47', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 
                                       'SOUTH EAST', 'SOUTH WEST'])

# %%
print(properties.shape)
print(properties.isna().sum())
# Out:
# (350, 38)
# Unnamed: 0              1
# City of London          0
# Barking & Dagenham      0
# Barnet                  0
# Bexley                  0
# Brent                   0
# Bromley                 0
# Camden                  0
# Croydon                 0
# Ealing                  0
# Enfield                 0
# Greenwich               0
# Hackney                 0
# Hammersmith & Fulham    0
# Haringey                0
# Harrow                  0
# Havering                0
# Hillingdon              0
# Hounslow                0
# Islington               0
# Kensington & Chelsea    0
# Kingston upon Thames    0
# Lambeth                 0
# Lewisham                0
# Merton                  0
# Newham                  0
# Redbridge               0
# Richmond upon Thames    0
# Southwark               0
# Sutton                  0
# Tower Hamlets           0
# Waltham Forest          0
# Wandsworth              0
# Westminster             0
# Inner London            0
# ...

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
properties.columns
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Inner London', 'Outer London', 'LONDON', 'England'],
#       dtype='object')

# %%
# The column for date is currently called "Unnamed:0"; will rename to "date"

properties.rename(columns = {'Unnamed: 0':'Date'}, inplace = True)

# %%
# As the dates are in rows and the boroughs are in columns, the data should be transposed for tidyness.

properties_trp = properties.transpose()

# %%
properties_trp.head()
# Out:
#                           0                    1                    2    \
# Date                      NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London      E09000001          91448.98487          82202.77314
# Barking & Dagenham  E09000002           50460.2266          51085.77983
# Barnet              E09000003          93284.51832          93190.16963
# Bexley              E09000004          64958.09036          64787.92069
#
#                                     3                    4    \
# Date                1995-03-01 00:00:00  1995-04-01 00:00:00
# City of London              79120.70256          77101.20804
# Barking & Dagenham          51268.96956          53133.50526
# Barnet                      92247.52435          90762.87492
# Bexley                      64367.49344          64277.66881
#
#                                     5                    6    \
# Date                1995-05-01 00:00:00  1995-06-01 00:00:00
# ...

# %%
# reset the index for properties_trp
properties_trp.reset_index(inplace=True)

# %%
properties_trp.head()
# Out:
#                 index          0                    1                    2  \
# 0                Date        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001          91448.98487          82202.77314
# 2  Barking & Dagenham  E09000002           50460.2266          51085.77983
# 3              Barnet  E09000003          93284.51832          93190.16963
# 4              Bexley  E09000004          64958.09036          64787.92069
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1          79120.70256          77101.20804          84409.14932
# 2          51268.96956          53133.50526          53042.24852
# 3          92247.52435          90762.87492          90258.00033
# 4          64367.49344          64277.66881          63997.13588
#
#                      6                    7                    8  ...  \
# ...

# %%
properties_trp.rename(columns=properties_trp.iloc[0], inplace = True)

# %%
properties_trp.head()
# Out:
#                  Date        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00  \
# 0                Date        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001          91448.98487          82202.77314
# 2  Barking & Dagenham  E09000002           50460.2266          51085.77983
# 3              Barnet  E09000003          93284.51832          93190.16963
# 4              Bexley  E09000004          64958.09036          64787.92069
#
#    1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1          79120.70256          77101.20804          84409.14932
# 2          51268.96956          53133.50526          53042.24852
# 3          92247.52435          90762.87492          90258.00033
# 4          64367.49344          64277.66881          63997.13588
#
#    1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...  \
# ...

# %%
# need to remove the duplicated row 0 vs column headers

properties_clean = properties_trp.drop(0)

# %%
properties_clean.head()
# Out:
#                  Date        NaT 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001         91448.98487         82202.77314
# 2  Barking & Dagenham  E09000002          50460.2266         51085.77983
# 3              Barnet  E09000003         93284.51832         93190.16963
# 4              Bexley  E09000004         64958.09036         64787.92069
# 5               Brent  E09000005         71306.56698         72022.26197
#
#   1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1         79120.70256         77101.20804         84409.14932
# 2         51268.96956         53133.50526         53042.24852
# 3         92247.52435         90762.87492         90258.00033
# 4         64367.49344         64277.66881         63997.13588
# 5         72015.76274         72965.63094         73704.04743
#
#   1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1         94900.51244         110128.0423         112329.4376  ...
# ...

# %%
# replace NaT with ID
properties_clean.rename(columns = {'Date':'Borough', pd.NaT : 'Area_code'}, inplace = True)

# %%
properties_clean.columns
# Out:
# Index([          'Borough',         'Area_code', 1995-01-01 00:00:00,
#        1995-02-01 00:00:00, 1995-03-01 00:00:00, 1995-04-01 00:00:00,
#        1995-05-01 00:00:00, 1995-06-01 00:00:00, 1995-07-01 00:00:00,
#        1995-08-01 00:00:00,
#        ...
#        2023-04-01 00:00:00, 2023-05-01 00:00:00, 2023-06-01 00:00:00,
#        2023-07-01 00:00:00, 2023-08-01 00:00:00, 2023-09-01 00:00:00,
#        2023-10-01 00:00:00, 2023-11-01 00:00:00, 2023-12-01 00:00:00,
#        2024-01-01 00:00:00],
#       dtype='object', length=351)

# %%
properties_clean.head()
# Out:
#               Borough  Area_code 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001         91448.98487         82202.77314
# 2  Barking & Dagenham  E09000002          50460.2266         51085.77983
# 3              Barnet  E09000003         93284.51832         93190.16963
# 4              Bexley  E09000004         64958.09036         64787.92069
# 5               Brent  E09000005         71306.56698         72022.26197
#
#   1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1         79120.70256         77101.20804         84409.14932
# 2         51268.96956         53133.50526         53042.24852
# 3         92247.52435         90762.87492         90258.00033
# 4         64367.49344         64277.66881         63997.13588
# 5         72015.76274         72965.63094         73704.04743
#
#   1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1         94900.51244         110128.0423         112329.4376  ...
# ...

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
# will now unpivot the date columns leaving only the Borough and Area Codes

properties_unpivot = properties_clean.melt(id_vars = ['Borough', 'Area_code'],  var_name = 'Date', value_name = 'Avg_price')

# %% [raw]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
properties_unpivot.shape
# Out:
# (12913, 4)

# %%
properties_unpivot.dtypes
# Out:
# Borough      object
# Area_code    object
# Date         object
# Avg_price    object
# dtype: object

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
properties_unpivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12913 entries, 0 to 12912
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Borough    12913 non-null  object
#  1   Area_code  12913 non-null  object
#  2   Date       12913 non-null  object
#  3   Avg_price  12913 non-null  object
# dtypes: object(4)
# memory usage: 403.7+ KB

# %%
# the Date and Avg_price Dtypes need to be updated to datetime and float, respectively.
properties_unpivot['Date'] = pd.to_datetime(properties_unpivot['Date'])
properties_unpivot['Avg_price']= properties_unpivot['Avg_price'].astype(float)

# %%
properties_unpivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12913 entries, 0 to 12912
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Borough    12913 non-null  object
#  1   Area_code  12913 non-null  object
#  2   Date       12913 non-null  datetime64[ns]
#  3   Avg_price  12913 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 403.7+ KB

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
#Before looking at any borough in particular, I will compare higher level entities.  For example inner and outer London vs London as a whole
properties_london = properties_unpivot.query('Borough in ["Inner London", "Outer London", "LONDON"]')

# %%
properties_london.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1047 entries, 33 to 12911
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Borough    1047 non-null   object
#  1   Area_code  1047 non-null   object
#  2   Date       1047 non-null   datetime64[ns]
#  3   Avg_price  1047 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 40.9+ KB

# %%
# line plot over time for Inner, Outer and London
london_pivot = properties_london.pivot_table(values="Avg_price", index="Date", columns="Borough")
london_pivot
# Out:
# Borough     Inner London        LONDON  Outer London
# Date
# 1995-01-01   78251.97650   74435.76052   72958.79836
# 1995-02-01   75885.70201   72777.93709   72937.88262
# 1995-03-01   76591.59947   73896.84204   72714.53478
# 1995-04-01   76851.56697   74455.28754   72591.92469
# 1995-05-01   79129.19443   75432.02786   72752.99414
# ...                  ...           ...           ...
# 2023-09-01  611136.00000  528750.00000  484227.00000
# 2023-10-01  610534.00000  519429.00000  482142.00000
# 2023-11-01  604523.00000  517123.00000  479230.00000
# 2023-12-01  590635.00000  505075.00000  474390.00000
# 2024-01-01  586090.00000  517726.00000  475872.00000
#
# [349 rows x 3 columns]

# %%
london_pivot.plot(legend=True)
plt.title("Growth of Avg home prices in London")
#plt.xlable("Date")
#plt.ylable("Avg home prices")
plt.show()

# %%
inner = ['Camden','Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Islington','Kensington & Chelsea', 'Lambeth', 'Lewisham', 'Southwark', 'Tower Hamlets',
         'Wandsworth','Westminster']

# %%
properties_inner = properties_unpivot.query('Borough in @inner')

# %%
properties_inner.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4188 entries, 6 to 12908
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Borough    4188 non-null   object
#  1   Area_code  4188 non-null   object
#  2   Date       4188 non-null   datetime64[ns]
#  3   Avg_price  4188 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 163.6+ KB

# %%
# line plot over time for Inner London boroughs
inner_pivot = properties_inner.pivot_table(values="Avg_price", index="Date", columns="Borough")
inner_pivot
# Out:
# Borough          Camden     Greenwich       Hackney  Hammersmith & Fulham  \
# Date
# 1995-01-01  120932.8881   62300.10169   61296.52637           124902.8602
# 1995-02-01  119508.8622   60993.26863   63187.08332           122087.7180
# 1995-03-01  120282.2131   61377.83464   63593.29935           120635.9467
# 1995-04-01  120097.8990   61927.72460   65139.64403           121424.6241
# 1995-05-01  119929.2782   63512.99103   66193.99212           124433.5390
# ...                 ...           ...           ...                   ...
# 2023-09-01  833351.0000  436382.00000  583473.00000           800002.0000
# 2023-10-01  846090.0000  431041.00000  593772.00000           766896.0000
# 2023-11-01  828300.0000  429598.00000  600545.00000           759614.0000
# 2023-12-01  857654.0000  439309.00000  588493.00000           727841.0000
# 2024-01-01  797248.0000  449502.00000  597973.00000           724641.0000
#
# ...

# %%
inner_pivot.plot(legend=True)
plt.title("Growth of Avg home prices in Inner London")
#plt.xlable("Date")
#plt.ylable("Avg home prices")
plt.show()

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
properties_unpivot['Year'] = properties_unpivot['Date'].dt.year

# %%
properties_unpivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12913 entries, 0 to 12912
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Borough    12913 non-null  object
#  1   Area_code  12913 non-null  object
#  2   Date       12913 non-null  datetime64[ns]
#  3   Avg_price  12913 non-null  float64
#  4   Year       12913 non-null  int32
# dtypes: datetime64[ns](1), float64(1), int32(1), object(2)
# memory usage: 454.1+ KB

# %%
properties_inner_year = properties_unpivot.query('Borough in @inner')

# %%
properties_inner_year
# Out:
#                     Borough  Area_code       Date     Avg_price  Year
# 6                    Camden  E09000007 1995-01-01  120932.88810  1995
# 10                Greenwich  E09000011 1995-01-01   62300.10169  1995
# 11                  Hackney  E09000012 1995-01-01   61296.52637  1995
# 12     Hammersmith & Fulham  E09000013 1995-01-01  124902.86020  1995
# 18                Islington  E09000019 1995-01-01   92516.48557  1995
# ...                     ...        ...        ...           ...   ...
# 12898              Lewisham  E09000023 2024-01-01  435010.00000  2024
# 12903             Southwark  E09000028 2024-01-01  514320.00000  2024
# 12905         Tower Hamlets  E09000030 2024-01-01  480719.00000  2024
# 12907            Wandsworth  E09000032 2024-01-01  612612.00000  2024
# 12908           Westminster  E09000033 2024-01-01  936715.00000  2024
#
# [4188 rows x 5 columns]

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
def create_price_ratio(borough, year1, year2):
    """Return the ratio of housing prices, comparing the price of a house in year2 to the price in year1
    for the provided borough"""
    #first we will filter the DataFrame to only contain the data for the borough specified
    df = properties_unpivot[properties_unpivot['Borough']== borough]
    #calculate the average housing prices for each year
    avg_year1 = df[df['Year'] ==year1]['Avg_price'].mean()
    avg_year2 = df[df['Year'] ==year2]['Avg_price'].mean()
    #calculate the ratio for the years provided
    price_ratio = avg_year1 / avg_year2
    return(price_ratio)

# %%
create_price_ratio('Kensington & Chelsea', 1998, 2018)
# Out:
# 0.19675491852791566

# %%
create_price_ratio('Westminster', 1998, 2018)
# Out:
# 0.1867914047302468

# %%
create_price_ratio('Greenwich', 1998, 2018)
# Out:
# 0.20995010893854218

# %%
create_price_ratio('Wandsworth', 1998, 2018)
# Out:
# 0.21018518091593216

# %%
create_price_ratio('Hammersmith & Fulham', 1998, 2018)
# Out:
# 0.24167443054605853

# %%
create_price_ratio('Inner London', 1998, 2018)
# Out:
# 0.19339152138506577

# %%
create_price_ratio('Outer London', 1998, 2018)
# Out:
# 0.22629811224913093

# %%
create_price_ratio('LONDON', 1998, 2018)
# Out:
# 0.2136854299558557

# %%
def create_price_ratio_dict(dframe, year1, year2):
    """Return the a dictionary containing the ratio of housing prices, comparing the price of a house in year2 to the price in year1
    for each borough in the dataframe"""
    #first we will initialize the empty dictionary:
    borough_to_ratio = {}

    #extract the boroughs column from the dataframe provided
    df=dframe
    borough = df['Borough']

    #iterate over list of boroughs
    for entry in borough:

        #first we will subset the DataFrame to only contain the data for the borough specified
        df2 = df[df['Borough']== entry]
        #calculate the average housing prices for each year
        avg_year1 = df2[df2['Year'] ==year1]['Avg_price'].mean()
        avg_year2 = df2[df2['Year'] ==year2]['Avg_price'].mean()
        #calculate the ratio for the years provided
        price_ratio = avg_year1 / avg_year2
        #add new value to dictionary
        borough_to_ratio[entry] = price_ratio
    return(borough_to_ratio)

# %%
#return the result
result = create_price_ratio_dict(properties_unpivot, 1998, 2018)
print(result)
# Out:
# {'City of London': 0.18862157770244364, 'Barking & Dagenham': 0.2042225623539368, 'Barnet': 0.229452741207858, 'Bexley': 0.23535076540630112, 'Brent': 0.2043086864360114, 'Bromley': 0.24421308489837307, 'Camden': 0.20261973503252542, 'Croydon': 0.23803288028014052, 'Ealing': 0.23194048191708758, 'Enfield': 0.23455064269011858, 'Greenwich': 0.20995010893854218, 'Hackney': 0.16133493530705734, 'Hammersmith & Fulham': 0.24167443054605853, 'Haringey': 0.19475619095546956, 'Harrow': 0.24635417785626296, 'Havering': 0.23120155787014757, 'Hillingdon': 0.23807975835429931, 'Hounslow': 0.25148317824115635, 'Islington': 0.20643891170300288, 'Kensington & Chelsea': 0.19675491852791566, 'Kingston upon Thames': 0.23416190234282552, 'Lambeth': 0.20170435486140822, 'Lewisham': 0.1835124676472171, 'Merton': 0.21091380604361798, 'Newham': 0.18848754146121072, 'Redbridge': 0.2236545053715767, 'Richmond upon Thames': 0.24967779731157863, 'Southwark': 0.18127484171283462, 'Sutton': 0.24280551426824518, 
# ...

# %%
final_df = pd.DataFrame.from_dict([result])
final_df
# Out:
#    City of London  Barking & Dagenham    Barnet    Bexley     Brent   Bromley  \
# 0        0.188622            0.204223  0.229453  0.235351  0.204309  0.244213
#
#     Camden   Croydon   Ealing   Enfield  ...  Southwark    Sutton  \
# 0  0.20262  0.238033  0.23194  0.234551  ...   0.181275  0.242806
#
#    Tower Hamlets  Waltham Forest  Wandsworth  Westminster  Inner London  \
# 0       0.216137        0.171387    0.210185     0.186791      0.193392
#
#    Outer London    LONDON   England
# 0      0.226298  0.213685  0.262436
#
# [1 rows x 37 columns]

# %%
final_transposed = final_df.transpose()

# %%
last_df = final_transposed.reset_index()
last_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   37 non-null     object
#  1   0       37 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 724.0+ bytes

# %%
last_df
last_df.rename(columns = {'index':'Borough', 0 : 'Price_Ratio'}, inplace = True)

# %%
last_df_sorted = last_df.sort_values(by='Price_Ratio')
last_df_sorted
# Out:
#                  Borough  Price_Ratio
# 11               Hackney     0.161335
# 30        Waltham Forest     0.171387
# 27             Southwark     0.181275
# 22              Lewisham     0.183512
# 32           Westminster     0.186791
# 24                Newham     0.188488
# 0         City of London     0.188622
# 33          Inner London     0.193392
# 13              Haringey     0.194756
# 19  Kensington & Chelsea     0.196755
# 21               Lambeth     0.201704
# 6                 Camden     0.202620
# 1     Barking & Dagenham     0.204223
# 4                  Brent     0.204309
# 18             Islington     0.206439
# 10             Greenwich     0.209950
# 31            Wandsworth     0.210185
# 23                Merton     0.210914
# 35                LONDON     0.213685
# 29         Tower Hamlets     0.216137
# 25             Redbridge     0.223655
# 34          Outer London     0.226298
# 2                 Barnet     0.229453
# 15              Havering     0.231202
# ...

# %%
last_df_sorted.set_index("Borough", inplace = True)

# %%
last_df_sorted.plot.barh()
# Out:
# <Axes: ylabel='Borough'>

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [markdown]
# ### 4. What did I discover about the housing prices in London?
#
# By use of a generating a price ratio, comparing 1998 to 2018, it shows that the largest growth in prices over the 2 decades occurred in Hackney.  In 1998, the average housing prices were roughly 88K pounds, whereas by 2018, that average grew to over half a million pounds.
#
# In order to arrive at this answer, I first researched what all of the columns were.  Meaning, there were only 32 boroughs but 45 columns in the original data file.  I found more information
# on the different boroughs and found that some of the columns were related to the 32 boroughs of London.  Essentially, Inner London, Outer London, and London were hierarchies into which the 32 boroughs fell.
#
# My initial thought was, could I visually identify if there was more growth within Inner vs Outer London as a way to narrow down my search. As noted with my line chart. Had I based it solely on that line initial line chart, I would have selected Kensington & Chelsea as the priciest borough. This seemed to be supported by my first pass a defining a function to calculate a price ratio by for a borough.
#
# However, thankfully the assignment suggested expanding the function to iterate through the list of all the boroughs to calculate the price ratio for all boroughs.  By doing that, is is now clearly Hackney, part of Outer London, that has experienced the most growth in average home pricing through the period of 1998 - 2018.  There for my first choice (based on trend charts) was Kinsington & Chelsea, which actually places 8th on the list when sorted by the price ratio.
#
# I can say that I learned that you may want to continue digging to better validate your results.
